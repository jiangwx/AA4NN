# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

origin_loss=[2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055]
origin_top1=[0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012]
origin_top5=[0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869]
prune_top1_loss=[2.1145,1.7314,1.4915,1.5947,1.5973,1.6011,1.6353,1.5162,2.192,1.7263,1.7437,1.7944,1.7497,2.2705,1.8012,1.7834,1.5233]
prune_top1_top1=[0.4576,0.5055,0.5556,0.5412,0.5467,0.5369,0.5275,0.5528,0.36025,0.502,0.5011,0.48,0.4959,0.3454,0.462,0.4835,0.5387]
prune_top1_top5=[0.8293,0.877,0.8935,0.894,0.889,0.8717,0.887,0.8935,0.81825,0.8641,0.8449,0.8394,0.8458,0.7238,0.8557,0.85,0.8739]
prune_loss_loss=[1.7571,1.6359,1.7796,1.6073,1.6308,1.6129,1.6249,1.4174,1.94410178,1.5989,1.725,1.818,1.5797,2.3715,1.5191,1.6152,1.5539]
prune_loss_top1=[0.5079,0.5303,0.4785,0.5388,0.5344,0.532,0.5347,0.573,0.414,0.5256,0.4998,0.4761,0.5281,0.3233,0.529,0.5126,0.5306]
prune_loss_top5=[0.8785,0.8904,0.8565,0.8938,0.8906,0.871,0.89,0.905,0.83175,0.8785,0.856,0.8264,0.8698,0.6935,0.8805,0.8699,0.8657]
_prune_top1_loss=[3.1352,4.1375,2.0292,1.9782,1.9301,1.9737,2.0132,2.504,2.195186191,2.61,2.5994,2.4552,2.0798,0.2572,2.5499,2.2347,1.9166]
_prune_top1_top1=[0.341,0.284,0.4783,0.4695,0.4965,0.4664,0.4748,0.4006,0.411,0.3774,0.3747,0.3897,0.4304,0.3311,0.3673,0.4057,0.449]
_prune_top1_top5=[0.7452,0.6695,0.8475,0.8435,0.8625,0.85,0.8389,0.7706,0.830333333,0.7228,0.7244,0.7633,0.8207,0.6818,0.7598,0.8004,0.8383]
_prune_loss_loss=[2.5371,4.0021,2.1639,2.1789,1.6889,2.0318,2.1081,2.5735,2.126271612,2.4643,2.2962,2.4473,2.0248,0.2392,2.4858,2.2043,1.8678]
_prune_loss_top1=[0.4051,0.2902,0.4607,0.4414,0.5298,0.4602,0.4612,0.403,0.41925,0.39516,0.413,0.3953,0.4505,0.3398,0.3806,0.4179,0.4541]
_prune_loss_top5=[0.815,0.6744,0.8282,0.8246,0.8875,0.837,0.8287,0.763,0.83625,0.752,0.76991,0.758,0.818,0.7064,0.7675,0.8079,0.8455]

# %%
plt.figure(figsize=(20,15))

plt.plot(origin_loss, lw = 1, label = 'origin loss')
plt.plot(origin_loss, 'b')

plt.plot(prune_top1_loss, lw = 1, label = 'prune basing top1\'s loss')
plt.plot(prune_top1_loss, 'ro')

plt.plot(_prune_top1_loss, lw = 1, label = '~prune basing top1\'s loss')
plt.plot(_prune_top1_loss, 'ro')

plt.legend(loc = 0) #图例位置自动

plt.grid(True)
plt.axis('tight')
plt.xlabel('CONV index')
plt.ylabel('loss')
plt.title('prune rate = 0.375',size=35)
plt.savefig('prune basing top1\'s loss, rate = 0.375' + ".png")
plt.show()

# %%
plt.figure(figsize=(20,15))

plt.plot(origin_loss, lw = 1, label = 'origin loss')
plt.plot(origin_loss, 'b')

plt.plot(prune_loss_loss, lw = 1, label = 'prune basing loss\'s loss')
plt.plot(prune_loss_loss, 'ro')

plt.plot(_prune_loss_loss, lw = 1, label = '~prune basing loss\'s loss')
plt.plot(_prune_loss_loss, 'ro')

plt.legend(loc = 0) #图例位置自动

plt.grid(True)
plt.axis('tight')
plt.xlabel('CONV index')
plt.ylabel('loss')
plt.title('prune rate = 0.375',size=35)
plt.savefig('prune basing loss\'s loss, rate = 0.375' + ".png")
plt.show()

# %%
plt.figure(figsize=(20,15))

plt.plot(origin_top1, lw = 1, label = 'origin top1')
plt.plot(origin_top1, 'b')

plt.plot(prune_top1_top1, lw = 1, label = 'prune basing top1\'s top1')
plt.plot(prune_top1_top1, 'ro')

plt.plot(_prune_top1_top1, lw = 1, label = '~prune basing top1\'s top1')
plt.plot(_prune_top1_top1, 'ro')

plt.legend(loc = 0) #图例位置自动

plt.grid(True)
plt.axis('tight')
plt.xlabel('CONV index')
plt.ylabel('top1')
plt.title('prune rate = 0.375',size=35)
plt.savefig('prune basing top1\'s top1, rate = 0.375' + ".png")
plt.show()

# %%
plt.figure(figsize=(20,15))

plt.plot(origin_top1, lw = 1, label = 'origin top1')
plt.plot(origin_top1, 'b')

plt.plot(prune_loss_top1, lw = 1, label = 'prune basing loss\'s top1')
plt.plot(prune_loss_top1, 'ro')

plt.plot(_prune_loss_top1, lw = 1, label = '~prune basing loss\'s top1')
plt.plot(_prune_loss_top1, 'ro')

plt.legend(loc = 0) #图例位置自动

plt.grid(True)
plt.axis('tight')
plt.xlabel('CONV index')
plt.ylabel('top1')
plt.title('prune rate = 0.375',size=35)
plt.savefig('prune basing loss\'s top1, rate = 0.375' + ".png")
plt.show()

# %%
plt.figure(figsize=(20,15))

plt.plot(origin_top5, lw = 1, label = 'origin top5')
plt.plot(origin_top5, 'b')

plt.plot(prune_top1_top5, lw = 1, label = 'prune basing top1\'s top5')
plt.plot(prune_top1_top5, 'ro')

plt.plot(_prune_top1_top5, lw = 1, label = '~prune basing top1\'s top5')
plt.plot(_prune_top1_top5, 'ro')

plt.legend(loc = 0) #图例位置自动

plt.grid(True)
plt.axis('tight')
plt.xlabel('CONV index')
plt.ylabel('top5')
plt.title('prune rate = 0.375',size=35)
plt.savefig('prune basing top1\'s top5, rate = 0.375' + ".png")
plt.show()

# %%
plt.figure(figsize=(20,15))

plt.plot(origin_top5, lw = 1, label = 'origin top5')
plt.plot(origin_top5, 'b')

plt.plot(prune_loss_top5, lw = 1, label = 'prune basing loss\'s top5')
plt.plot(prune_loss_top5, 'ro')

plt.plot(_prune_loss_top5, lw = 1, label = '~prune basing loss\'s top5')
plt.plot(_prune_loss_top5, 'ro')

plt.legend(loc = 0) #图例位置自动

plt.grid(True)
plt.axis('tight')
plt.xlabel('CONV index')
plt.ylabel('top5')
plt.title('prune rate = 0.375',size=35)
plt.savefig('prune basing loss\'s top5, rate = 0.375' + ".png")
plt.show()

# %%
origin_loss=[2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055,2.0055]
origin_top1=[0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012,0.5012]
origin_top5=[0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869,0.869]
prune_top1_loss=[2.1145,1.7314,1.4915,1.5947,1.5973,1.6011,1.6353,1.5162,1.5671,1.7263,1.7437,1.7944,1.7497,2.2705,1.8012,1.7834,1.5233]
prune_top1_top1=[0.4576,0.5055,0.5556,0.5412,0.5467,0.5369,0.5275,0.5528,0.5284,0.502,0.5011,0.48,0.4959,0.3454,0.462,0.4835,0.5387]
prune_top1_top5=[0.8293,0.877,0.8935,0.894,0.889,0.8717,0.887,0.8935,0.8926,0.8641,0.8449,0.8394,0.8458,0.7238,0.8557,0.85,0.8739]
prune_loss_loss=[1.7571,1.6359,1.7796,1.6073,1.6308,1.6129,1.6249,1.4174,1.5249,1.5989,1.725,1.818,1.5797,2.3715,1.5191,1.6152,1.5539]
prune_loss_top1=[0.5079,0.5303,0.4785,0.5388,0.5344,0.532,0.5347,0.573,0.5376,0.5256,0.4998,0.4761,0.5281,0.3233,0.529,0.5126,0.5306]
prune_loss_top5=[0.8785,0.8904,0.8565,0.8938,0.8906,0.871,0.89,0.905,0.8927,0.8785,0.856,0.8264,0.8698,0.6935,0.8805,0.8699,0.8657]
_prune_top1_loss=[3.1352,4.1375,2.0292,1.9782,1.9301,1.9737,2.0132,2.504,2.2727,2.61,2.5994,2.4552,2.0798,0.2572,2.5499,2.2347,1.9166]
_prune_top1_top1=[0.341,0.284,0.4783,0.4695,0.4965,0.4664,0.4748,0.4006,0.4309,0.3774,0.3747,0.3897,0.4304,0.3311,0.3673,0.4057,0.449]
_prune_top1_top5=[0.7452,0.6695,0.8475,0.8435,0.8625,0.85,0.8389,0.7706,0.8181,0.7228,0.7244,0.7633,0.8207,0.6818,0.7598,0.8004,0.8383]
_prune_loss_loss=[2.5371,4.0021,2.1639,2.1789,1.6889,2.0318,2.1081,2.5735,2.1262,2.4643,2.2962,2.4473,2.0248,0.2392,2.4858,2.2043,1.8678]
_prune_loss_top1=[0.4051,0.2902,0.4607,0.4414,0.5298,0.4602,0.4612,0.403,0.4447,0.39516,0.413,0.3953,0.4505,0.3398,0.3806,0.4179,0.4541]
_prune_loss_top5=[0.815,0.6744,0.8282,0.8246,0.8875,0.837,0.8287,0.763,0.8209,0.752,0.76991,0.758,0.818,0.7064,0.7675,0.8079,0.8455]

# %%
plt.figure(figsize=(20,15))

plt.plot(origin_loss, lw = 1, label = 'origin loss')
plt.plot(origin_loss, 'b')

plt.plot(prune_top1_loss, lw = 1, label = 'prune basing top1\'s loss')
plt.plot(prune_top1_loss, 'ro')

plt.plot(_prune_top1_loss, lw = 1, label = '~prune basing top1\'s loss')
plt.plot(_prune_top1_loss, 'ro')

plt.legend(loc = 0) #图例位置自动

plt.grid(True)
plt.axis('tight')
plt.xlabel('CONV index')
plt.ylabel('loss')
plt.title('prune rate = 0.375, conv9 rate = 0.25',size=35)
plt.savefig('prune basing top1\'s loss, rate = 0.375, conv9 rate = 0.25' + ".png")
plt.show()

# %%
plt.figure(figsize=(20,15))

plt.plot(origin_top5, lw = 1, label = 'origin top5')
plt.plot(origin_top5, 'b')

plt.plot(prune_top1_top5, lw = 1, label = 'prune basing top1\'s top5')
plt.plot(prune_top1_top5, 'ro')

plt.plot(_prune_top1_top5, lw = 1, label = '~prune basing top1\'s top5')
plt.plot(_prune_top1_top5, 'ro')

plt.legend(loc = 0) #图例位置自动

plt.grid(True)
plt.axis('tight')
plt.xlabel('CONV index')
plt.ylabel('top5')
plt.title('prune rate = 0.375, conv9 rate = 0.25',size=35)
plt.savefig('prune basing top1\'s top5, rate = 0.375, conv9 rate = 0.25' + ".png")
plt.show()
